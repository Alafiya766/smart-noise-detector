# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Smart Noise Detector — Notebook\n",
    "Explore `db.sqlite3`, plot readings, and test API"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "execution_count": 1,
   "outputs": [],
   "source": [
    "import sqlite3\n",
    "import pandas as pd\n",
    "import matplotlib.pyplot as plt\n",
    "\n",
    "DB_PATH = 'db.sqlite3'\n",
    "conn = sqlite3.connect(DB_PATH)\n",
    "df = pd.read_sql('SELECT * FROM readings ORDER BY timestamp ASC', conn)\n",
    "conn.close()\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "execution_count": 2,
   "outputs": [],
   "source": [
    "plt.figure(figsize=(10,4))\n",
    "plt.plot(pd.to_datetime(df['timestamp']), df['db_level'], marker='o')\n",
    "plt.xlabel('Time')\n",
    "plt.ylabel('dB Level')\n",
    "plt.title('Noise Levels Over Time')\n",
    "plt.xticks(rotation=45)\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "execution_count": 3,
   "outputs": [],
   "source": [
    "import requests\n",
    "\n",
    "# Example: test API endpoint (make sure Flask server is running)\n",
    "url = 'http://127.0.0.1:5000/readings'\n",
    "response = requests.get(url)\n",
    "response.json()"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.9"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
# Out:
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {},
#    'source': ['# Smart Noise Detector — Notebook\n',
#     'Explore `db.sqlite3`, plot readings, and test API']},
#   {'cell_type': 'code',
#    'metadata': {},
#    'execution_count': 1,
#    'outputs': [],
#    'source': ['import sqlite3\n',
#     'import pandas as pd\n',
#     'import matplotlib.pyplot as plt\n',
#     '\n',
#     "DB_PATH = 'db.sqlite3'\n",
#     'conn = sqlite3.connect(DB_PATH)\n',
#     "df = pd.read_sql('SELECT * FROM readings ORDER BY timestamp ASC', conn)\n",
#     'conn.close()\n',
#     'df.head()']},
#   {'cell_type': 'code',
#    'metadata': {},
#    'execution_count': 2,
#    'outputs': [],
#    'source': ['plt.figure(figsize=(10,4))\n',
#     "plt.plot(pd.to_datetime(df['timestamp']), df['db_level'], marker='o')\n",
#     "plt.xlabel('Time')\n",
#     "plt.ylabel('dB Level')\n",
#     "plt.title('Noise Levels Over Time')\n",
#     'plt.xticks(rotation=45)\n',
#     'plt.tight_layout()\n',
# ...
